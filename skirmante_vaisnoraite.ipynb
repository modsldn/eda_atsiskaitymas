# %% [markdown]
# # Pirma dalis

# %% [markdown]
# ## No 1

# %% [markdown]
# <font color='red'> Erikas Švažas:
#
# 1. Šaunu, kad panaudotas nb_black! Puiki praktika!
#
# </font>

# %%
# scikit-learn
# seaborn
# jupyter
# nb_black


# !pip install nb_black
# %load_ext nb_black
import nb_black
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import requests

# %% [markdown]
# ## No 2

# %%
URL = "https://www.registrucentras.lt/aduomenys/?byla=JAR_FA_RODIKLIAI_BLNS_2021.csv"
# 2. download the data behind the URL
response = requests.get(URL)
# 3. Open the response into a new file balanso_2021
open("balanso_2021", "wb").write(response.content)
data_balansas_21 = pd.read_csv("balanso_2021", sep=",")
data_balansas_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120850 entries, 0 to 120849
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   obj_kodas                     120850 non-null  int64
#  1   obj_pav                       120850 non-null  object
#  2   form_kodas                    120850 non-null  int64
#  3   form_pav                      120850 non-null  object
#  4   stat_statusas                 120850 non-null  int64
#  5   stat_pav                      120850 non-null  object
#  6   template_id                   120850 non-null  object
#  7   template_name                 120850 non-null  object
#  8   standard_id                   120850 non-null  object
#  9   standard_name                 120850 non-null  object
#  10  laikotarpis_nuo               120850 non-null  object
#  11  laikotarpis_iki               120850 non-null  object
# ...

# %%
URL = "https://www.registrucentras.lt/aduomenys/?byla=JAR_FA_RODIKLIAI_BLNS_2020.csv"
# 2. download the data behind the URL
response = requests.get(URL)
# 3. Open the response into a new file balanso_2020
open("balanso_2020", "wb").write(response.content)
data_balansas_20 = pd.read_csv("balanso_2020", sep=",")
data_balansas_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106318 entries, 0 to 106317
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   obj_kodas                     106318 non-null  int64
#  1   obj_pav                       106318 non-null  object
#  2   form_kodas                    106318 non-null  int64
#  3   form_pav                      106318 non-null  object
#  4   stat_statusas                 106318 non-null  int64
#  5   stat_pav                      106318 non-null  object
#  6   template_id                   106318 non-null  object
#  7   template_name                 106318 non-null  object
#  8   standard_id                   106318 non-null  object
#  9   standard_name                 106318 non-null  object
#  10  laikotarpis_nuo               106318 non-null  object
#  11  laikotarpis_iki               106318 non-null  object
# ...

# %%
URL = "https://www.registrucentras.lt/aduomenys/?byla=JAR_FA_RODIKLIAI_PLNA_2021.csv"
# 2. download the data behind the URL
response = requests.get(URL)
# 3. Open the response into a new file balanso_2021
open("pelnas_2021", "wb").write(response.content)
data_pelnas_21 = pd.read_csv("pelnas_2021", sep=",")
data_pelnas_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110227 entries, 0 to 110226
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   obj_kodas                   110227 non-null  int64
#  1   obj_pav                     110227 non-null  object
#  2   form_kodas                  110227 non-null  int64
#  3   form_pav                    110227 non-null  object
#  4   stat_statusas               110227 non-null  int64
#  5   stat_pav                    110227 non-null  object
#  6   template_id                 110227 non-null  object
#  7   template_name               110227 non-null  object
#  8   standard_id                 110227 non-null  object
#  9   standard_name               110227 non-null  object
#  10  laikotarpis_nuo             110227 non-null  object
#  11  laikotarpis_iki             110227 non-null  object
#  12  reg_date                    110227 non-null  object
# ...

# %%
import requests

URL = "https://www.registrucentras.lt/aduomenys/?byla=JAR_FA_RODIKLIAI_PLNA_2020.csv"
# 2. download the data behind the URL
response = requests.get(URL)
# 3. Open the response into a new file balanso_2020
open("pelnas_2020", "wb").write(response.content)
data_pelnas_20 = pd.read_csv("pelnas_2020", sep=",")
data_pelnas_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96616 entries, 0 to 96615
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   obj_kodas                   96616 non-null  int64
#  1   obj_pav                     96616 non-null  object
#  2   form_kodas                  96616 non-null  int64
#  3   form_pav                    96616 non-null  object
#  4   stat_statusas               96616 non-null  int64
#  5   stat_pav                    96616 non-null  object
#  6   template_id                 96616 non-null  object
#  7   template_name               96616 non-null  object
#  8   standard_id                 96616 non-null  object
#  9   standard_name               96616 non-null  object
#  10  laikotarpis_nuo             96616 non-null  object
#  11  laikotarpis_iki             96616 non-null  object
#  12  reg_date                    96616 non-null  object
# ...

# %% [markdown]
# <font color='red'> Erikas Švažas:
#
# Teisingai jei norima pirma atsisiųsti failą! Paprastesnė alternatyva tiesiog nusiskaityti iš remote:
# ````
# pd.read_csv(
#     "https://www.registrucentras.lt/aduomenys/?byla=JAR_FA_RODIKLIAI_BLNS_2020.csv"
# )
# ````
#
# </font>

# %% [markdown]
# ## No 3

# %% [markdown]
# ## A ir B

# %%
data_balansas_21.info()
data_balansas_20.info()
data_pelnas_20.info()
data_pelnas_21.info()


## B
data_balansas_20.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120850 entries, 0 to 120849
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   obj_kodas                     120850 non-null  int64
#  1   obj_pav                       120850 non-null  object
#  2   form_kodas                    120850 non-null  int64
#  3   form_pav                      120850 non-null  object
#  4   stat_statusas                 120850 non-null  int64
#  5   stat_pav                      120850 non-null  object
#  6   template_id                   120850 non-null  object
#  7   template_name                 120850 non-null  object
#  8   standard_id                   120850 non-null  object
#  9   standard_name                 120850 non-null  object
#  10  laikotarpis_nuo               120850 non-null  object
#  11  laikotarpis_iki               120850 non-null  object
# ...

# %% [markdown]
# <font color='red'> Erikas Švažas:
#
# Iš pateiktos informacijos nėra akivaidzu ką reiškia skirtingi laukai. Reikia *domain knowledge* arba ieškoti informacijos greta pagrindinių šaltinių (ypač šalia duomenų iš valstybinių kompanijų). Kad geriau suprasti skirtingus duomenų laukus, galime vadovautis Registrų centro pateiktomis *"Duomenų rinkinio struktūros"*.
# Būtent iš šio failo galime spręsti ką reiškia skirtingi laukai ir šiuo atveju buvo norima inspektuoti stulpelių pavadinimus ir jų reikšmes (ne duomenų tipus) [-0.3taško]
# </font>

# %% [markdown]
# ## C

# %%
df_2021 = pd.concat([data_balansas_21, data_pelnas_21], axis=1, join="inner")
df_2021 = df_2021.loc[:, ~df_2021.columns.duplicated()]
df_2021.info()
df_2021 = df_2021.drop(["formavimo_data"], axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110227 entries, 0 to 110226
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   obj_kodas                     110227 non-null  int64
#  1   obj_pav                       110227 non-null  object
#  2   form_kodas                    110227 non-null  int64
#  3   form_pav                      110227 non-null  object
#  4   stat_statusas                 110227 non-null  int64
#  5   stat_pav                      110227 non-null  object
#  6   template_id                   110227 non-null  object
#  7   template_name                 110227 non-null  object
#  8   standard_id                   110227 non-null  object
#  9   standard_name                 110227 non-null  object
#  10  laikotarpis_nuo               110227 non-null  object
#  11  laikotarpis_iki               110227 non-null  object
# ...

# %%
df_2020 = pd.concat([data_balansas_20, data_pelnas_20], axis=1, join="inner")
df_2020 = df_2020.loc[:, ~df_2020.columns.duplicated()]
df_2020.info()
df_2020 = df_2020.drop(["formavimo_data"], axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96616 entries, 0 to 96615
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   obj_kodas                     96616 non-null  int64
#  1   obj_pav                       96616 non-null  object
#  2   form_kodas                    96616 non-null  int64
#  3   form_pav                      96616 non-null  object
#  4   stat_statusas                 96616 non-null  int64
#  5   stat_pav                      96616 non-null  object
#  6   template_id                   96616 non-null  object
#  7   template_name                 96616 non-null  object
#  8   standard_id                   96616 non-null  object
#  9   standard_name                 96616 non-null  object
#  10  laikotarpis_nuo               96616 non-null  object
#  11  laikotarpis_iki               96616 non-null  object
# ...

# %%
df_2020.dtypes.equals(df_2021.dtypes)
# Out:
# True

# %% [markdown]
# ## D

# %%
# When Python stores a string, it stores quite a bit of metadata: the overhead of the Python object itself,
# to begin with, and then a bunch of metadata about the string, and finally the string itself.
# When a column is Object type, it does not necessarily mean that all the values will be string.

# they can all be numbers, or a mixture of string, integers and floats.

# With this discrepancy present, you can not do any string operation on the column straightaway.
# Out:
# Object `??` not found.

# %% [markdown]
# <font color='red'> Erikas Švažas:
# Taip, teisingai. Dar pridėčiau, kad *everything is an object in Python* ir jei *Pandas* negali atpažinti duomenų tipo (ar tai integer ar string), by default bus *object*. Kiekvineas objektas turės skirtingas funkcijas ir savybes - pavyzdžiui norint naudoti string tipui būdingas fcijas .str.contains() reikės pradžioje atlikti konvertavimą į šį duomenų tipą.
# </font>

# %% [markdown]
# ## E

# %%
df_2020.isnull().sum().nlargest(1)
# Out:
# pelnas_pries_apmokestinima    30365
# dtype: int64

# %%
df_2021.isnull().sum().nlargest(1)
# Out:
# pelnas_pries_apmokestinima    34755
# dtype: int64

# %% [markdown]
# <font color='red'> Erikas Švažas:
#
# šauniai panaudotos *Pandas* intrinsic fcijos. Be aware apie open-source paketus (pav [šis](https://github.com/ResidentMario/missingno)) skirtus tokiom užduotim spręsti.
# </font>

# %% [markdown]
# ## F and I

# %% [markdown]
# <font color='red'> Erikas Švažas:
# Uždavinys norėjo rasti mažiausią stulpelių aibę su kuriais vis dar galėtume unikaliai identifikuoti kiekvieną eilutę. Todėl šiuo atveju ieškome visiškai priešingai - ieškome stulpelio kuris turi maksimaliai unikalių verčių ir žiūrime ar prie jo pridėjus kitą stulpelį galime unikaliai identifikuoti visą datasetą/ Atsakymas: obj_kodas ir laikotarpis_nuo [-0.3 taško]

# %%
# unikaliu
df_2020.nunique().nlargest(1)
# Out:
# obj_kodas    87992
# dtype: int64

# %%
unique_counts = df_2020.nunique()
lowest_distinct = unique_counts.min()
lowest_distinct_columns = unique_counts[unique_counts == lowest_distinct].index.tolist()

result = pd.DataFrame({col: df_2020[col].unique() for col in lowest_distinct_columns})
result
# Out:
#                                        standard_name
# 0  BALANSAS (Neribotos civilinės atsakomybės juri...
# 1                        FINANSINĖS BŪKLĖS ATASKAITA
# 2                            BALANSAS (Sutrumpintas)
# 3                                 BALANSAS (Trumpas)
# 4                                           BALANSAS
# 5                         BALANSAS (mažųjų bendrijų)
# 6                        METINĖS ATASKAITOS DUOMENYS
# 7    BALANSAS(Finansinės būklės ataskaitos duomenys)
# 8                            BALANSAS (sutrumpintas)

# %%
unique_counts = df_2021.nunique()
lowest_distinct = unique_counts.min()
lowest_distinct_columns = unique_counts[unique_counts == lowest_distinct].index.tolist()

result = pd.DataFrame({col: df_2021[col].unique() for col in lowest_distinct_columns})
result
# Out:
#                                        standard_name
# 0                        FINANSINĖS BŪKLĖS ATASKAITA
# 1                                 BALANSAS (Trumpas)
# 2                                           BALANSAS
# 3  BALANSAS (Neribotos civilinės atsakomybės juri...
# 4                            BALANSAS (Sutrumpintas)
# 5                        METINĖS ATASKAITOS DUOMENYS
# 6                         BALANSAS (mažųjų bendrijų)
# 7    BALANSAS(Finansinės būklės ataskaitos duomenys)
# 8  BALANSAS (Neribotos civilinės atsakomybės juri...
# 9                            BALANSAS (sutrumpintas)

# %% [markdown]
# # Antra dalis

# %% [markdown]
# ## 4

# %%
pav_su_thermo20 = df_2021[df_2021["obj_pav"].str.contains("Thermo Fisher", regex=False)]
pav_su_thermo20["obj_pav"].tolist()
# Out:
# ['UAB "Thermo Fisher Scientific Vector Senior Holdings II"',
#  'UAB "Thermo Fisher Scientific Vector Senior Holdings I"',
#  'UAB "Thermo Fisher Scientific Baltics"',
#  'UAB "Thermo Fisher Scientific Vector Holdings"']

# %%
pav_su_thermo = df_2020[df_2020["obj_pav"].str.contains("Thermo Fisher", regex=False)]
pav_su_thermo["obj_pav"].tolist()
# Out:
# ['UAB "Thermo Fisher Scientific Vector Holdings"',
#  'UAB "Thermo Fisher Scientific Baltics"',
#  'UAB "Thermo Fisher Scientific Vector Senior Holdings I"',
#  'UAB "Thermo Fisher Scientific Vector Senior Holdings II"']

# %%
df_2020.head(10)
# Out:
#    obj_kodas                                            obj_pav  form_kodas  \
# 0  305217929                                      MB "Jantaris"         960
# 1  304127368  Alytaus neformaliojo švietimo centras "Toleran...         630
# 2  304759186              Uždaroji akcinė bendrovė "Balsana LT"         310
# 3  191160250                 Kretingos sporto klubas "Žalgiris"         630
# 4  304512862                                       UAB "Tedėja"         310
# 5  222022510                 Uždaroji akcinė bendrovė "RUTONIS"         310
# 6  304259900                                      UAB "Algimta"         310
# 7  304085969                                 MB "Mondri darbai"         960
# 8  304536436                                          Kimen UAB         310
# 9  300080316                                      UAB "Belgita"         310
#
#                    form_pav  stat_statusas                       stat_pav  \
# ...

# %% [markdown]
# ## 5

# %%
df_1 = data_pelnas_21.loc[
    data_pelnas_21["form_pav"].isin(["Uždaroji akcinė bendrovė", "Mažoji bendrija"])
]
df_1.head(20)
df_1["form_pav2"] = np.where(
    df_1["obj_pav"].map(lambda x: x.split(" ")[0] == "MB"),
    "Mažoji bendrija",
    "Uždaroji akcinė bendrovė",
)
df_1["form_pav2"].head(20)

df_1["is_equal"] = df_1["form_pav"] == df_1["form_pav2"]
sum_true = np.count_nonzero(df_1["is_equal"])
percentage = (sum_true / df_1["is_equal"].count() * 100).round(2)
percentage
# Out:
# C:\Users\adm\AppData\Local\Temp\ipykernel_10588\1722334028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1["form_pav2"] = np.where(
# C:\Users\adm\AppData\Local\Temp\ipykernel_10588\1722334028.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1["is_equal"] = df_1["form_pav"] == df_1["form_pav2"]
# 98.59

# %% [markdown]
# ## 6

# %%
df_abu_metai = pd.concat([df_2021, df_2020], ignore_index=True)
mean_pelno_ir_kapitalo = (
    df_abu_metai.groupby("form_pav")["pelnas_pries_apmokestinima", "nuosavas_kapitalas"]
    .mean()
    .round()
)
mean_pelno_ir_kapitalo
# Out:
# C:\Users\adm\AppData\Local\Temp\ipykernel_10588\3947489978.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_abu_metai.groupby("form_pav")["pelnas_pries_apmokestinima", "nuosavas_kapitalas"]
#                                           pelnas_pries_apmokestinima  \
# form_pav
# Akcinė bendrovė                                             280817.0
# Asociacija                                                   91840.0
# Bendrija                                                         0.0
# Biudžetinė įstaiga                                           84398.0
# Individuali įmonė                                            35042.0
# Komanditinė ūkinė bendrija                                  -58009.0
# Kooperatinė bendrovė                                         39403.0
# Labdaros ir paramos fondas                                   27718.0
# ...

# %% [markdown]
# ## 7

# %%
tik_MB = df_abu_metai[df_abu_metai["form_pav"] == "Mažoji bendrija"]
MB_higher_than_median = tik_MB[
    tik_MB["nuosavas_kapitalas"] > tik_MB["nuosavas_kapitalas"].median()
]
MB_higher_than_median["obj_pav"].drop_duplicates().reset_index(drop=True)
# Out:
# 0       MB Saviugdos mokymų centras
# 1                      MB "Armidas"
# 2                      MB "Minhusa"
# 3                MB "Moa atradimai"
# 4                      MB "Gabaiva"
#                    ...
# 9537                  MB "Minkruta"
# 9538                     MB "Bolvė"
# 9539                    MB "Stegra"
# 9540                    MB "Federa"
# 9541                  MB "Digerita"
# Name: obj_pav, Length: 9542, dtype: object

# %%
tik_UAB = df_abu_metai[df_abu_metai["form_pav"] == "Uždaroji akcinė bendrovė"]
# ieskau obj.kodo nes jis yra unikalus, kadangi yra imoniu su tais paciais vardais
UAB_higher = tik_UAB[
    tik_UAB["nuosavas_kapitalas"] > tik_UAB["nuosavas_kapitalas"].median()
]
UAB_higher["obj_kodas"].drop_duplicates().reset_index(drop=True)
# Out:
# 0        303095031
# 1        305224119
# 2        304484181
# 3        161645290
# 4        300115030
#            ...
# 41877    126135547
# 41878    305039273
# 41879    134839832
# 41880    302812416
# 41881    184627344
# Name: obj_kodas, Length: 41882, dtype: int64

# %% [markdown]
# ## 8

# %%
top_nuosavas = pd.set_option("max_colwidth", None)
top_nuosavas = df_2021[
    df_2021["nuosavas_kapitalas"] > df_2021["nuosavas_kapitalas"].quantile(0.99)
]

top_nuosavas[["obj_kodas", "obj_pav", "nuosavas_kapitalas"]].sort_values(
    by="nuosavas_kapitalas", ascending=False
).head(10)

#
#AB "Energijos skirstymo operatorius"
#UAB "Thermo Fisher Scientific Baltics"
# Out:
#        obj_kodas                                                   obj_pav  \
# 54243  305115931            UAB "Thermo Fisher Scientific Vector Holdings"
# 25845  305115970   UAB "Thermo Fisher Scientific Vector Senior Holdings I"
# 16978  305115956  UAB "Thermo Fisher Scientific Vector Senior Holdings II"
# 62819  188710638      Valstybės įmonė Lietuvos automobilių kelių direkcija
# 39828  302608755               Uždaroji akcinė bendrovė "Vilniaus prekyba"
# 74818  301844044                                        AB "Ignitis grupė"
# 46428  122351387                    UAB "Thermo Fisher Scientific Baltics"
# 93471  110053842                  Akcinė bendrovė "Lietuvos geležinkeliai"
# 94826  305202934                                            AB "LTG Infra"
# 86688  304151376                      AB "Energijos skirstymo operatorius"
#
#        nuosavas_kapitalas
# 54243        3.898038e+09
# 25845        3.898038e+09
# 16978        2.950793e+09
# 62819        2.693140e+09
# ...

# %% [markdown]
# ## 9

# %%
df_abu_metai["reg_date"] = pd.to_datetime(df_abu_metai["reg_date"])
df_abu_metai["year"] = df_abu_metai["reg_date"].dt.year
df_abu_metai["month"] = df_abu_metai["reg_date"].dt.month

df_abu_metai.groupby(["form_pav", "year"])["year"].count().sort_values().plot(
    kind="bar",
    ylabel="Vienetų skaičius",
    title="Juridinių asmenų skaičius 2020 ir 2021 metais",
)
# Out:
# <AxesSubplot:title={'center':'Juridinių asmenų skaičius 2020 ir 2021 metais'}, xlabel='form_pav,year', ylabel='Vienetų skaičius'>

# %%
### matplot 


fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.4

df_abu_metai.form_pav.plot(kind='bar', color='red', ax=ax, width=width, position=1)
df_abu_metai.form_pav.plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_title('Juridinių asmenų skaičius 2020 ir 2021 metais'
ax.set_ylabel('')
ax2.set_ylabel('')

plt.show()

# %%
## seaborn

sns.countplot(data=df_abu_metai, x="10form_pav", hue="year").tick_params(
    axis="x", rotation=90
)
plt.ylabel("Vienetų skaičius")
plt.title("Juridinių asmenų skaičius 2020 ir 2021 metais")
# Out:
# Text(0.5, 1.0, 'Juridinių asmenų skaičius 2020 ir 2021 metais')

# %%
## matplot
labels = df_abu_metai['form_pav']
l_2020 = df_abu_metai[df_abu_metai['year']== 2020]['form_pav'].count()
l_2021 = df_abu_metai[df_abu_metai['year']== 2021]['form_pav'].count()

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, l_2020, width, label='2020_count')
rects2 = ax.bar(x + width/2, l_2021, width, label='2021_count')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('vienetų skaičius')
ax.set_title('Juridinių asmenų skaičius 2020 ir 2021 metais')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# ## 10

# %% [markdown]
# Kurį mėnesį buvo įregistruota
# daugiausiai juridinių asmenų 2020 ir
# 2021 metais? Atvaizduokite stulpelinę
# diagramą. [0.4 taško]

# %%
sns.countplot(data=df_abu_metai, x="month", hue="year")
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %% [markdown]
# ## 11

# %%
Vizualiai atvaizduoti juridinių asmenų statuso pasiskirstymą kiekvienais metais. [0.4
taško]

# %%
df_abu_metai.groupby(["stat_pav", "year"])["stat_pav"].count().sort_values().plot(
    kind="bar",
    ylabel="Vienetų skaičius",
    title="statusao pasiskirtymas 2020 ir 2021 metais",
)
# Out:
# <AxesSubplot:title={'center':'Juridinių asmenų skaičius 2020 ir 2021 metais'}, xlabel='stat_pav,year', ylabel='Vienetų skaičius'>

# %%
sns.countplot(data=df_abu_metai, x="month", hue="year")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1992\267112791.py in <cell line: 1>()
# ----> 1 sns.countplot(data=df_abu_metai, x="month", hue="year")
#
# NameError: name 'df_abu_metai' is not defined

# %%
df_abu_metai.stat_pav.unique()
# Out:
# array(['Teisinis stat neįregistruotas', 'Likviduojamas dėl bankroto',
#        'Išregistruotas', 'Likviduojamas', 'Inicijuojamas likvidavimas',
#        'Bankrutuojantis', 'Reorganizuojamas', 'Restruktūrizuojamas',
#        'Pertvarkomas', 'Bankrutavęs', 'Dalyvaujantis reorganizavime',
#        'Dalyvaujantis atskyrime', 'JA jung peržengiant 1 valst',
#        'JA dal 1 valst ribas jung'], dtype=object)

# %% [markdown]
# ## 12

# %%
Kiekvienai įmonei apskaičiuoti tendenciją. Jei “grynasis_pelnas” +
“nuosavas_kapitalas” 2021 metais buvo didesnis už 2020 metais deklaruotą, tai
tendencija “teigiama”, jei ne - “neigiama”. Atvaizduoti tendencijos duomenis
stulpelinėje diagramoje. [0.4 taško]

# %%
Surasti UAB ir MB įmones, kurios 2020 vykdė veiklą, o 2021 - bankrutavo.
Bankrutavusių įmonių statusai: “Bankrutavęs”, “Bankrutuojantis”, “Išregistruotas”,
“Inicijuojamas likvidavimas”, “Likviduojamas”, “Likviduojamas dėl bankroto”. Toliau
veiklą vykdanti įmonė pažymėta "Teisinis stat neįregistruotas" statusu. Kokia
bankrutavusių įmonių “nuosavas_kapitalas”suma 2021 metais? Kokia bankrutavusių
įmonių “grynasis_pelnas” suma 2021 metais? Palyginti šias sumas su veikiančių
įmonių atitinkamomis sumomis. [0.4 taško]

# %%
df_abu_metai_UAB_MB = df_abu_metai[
    df_abu_metai["form_pav"].isin(["Mažoji bendrija", "Uždaroji akcinė bendrovė"])
]


df_2020_veike = df_abu_metai_UAB_MB[
    (df_abu_metai_UAB_MB["stat_pav"] == "Teisinis stat neįregistruotas")
    & (df_abu_metai_UAB_MB["year"] == 2020)
]
df_2020_veike

df_2021_neveike = df_abu_metai_UAB_MB[
    (df_abu_metai_UAB_MB["stat_pav"] != "Teisinis stat neįregistruotas")
    & (df_abu_metai_UAB_MB["year"] == 2021)
]
df_2021_bankrutavo = df_2020_veike[
    df_2020_veike["obj_kodas"].isin(df_2021_neveike["obj_kodas"])
]
df_2021_bankrutavo
# Out:
# Empty DataFrame
# Columns: [obj_kodas, obj_pav, form_kodas, form_pav, stat_statusas, stat_pav, template_id, template_name, standard_id, standard_name, laikotarpis_nuo, laikotarpis_iki, reg_date, nuosavas_kapitalas, mok_sumos_ir_isipareigojimai, ilgalaikis_turtas, trumpalaikis_turtas, formavimo_data, pelnas_pries_apmokestinima, grynasis_pelnas, pardavimo_pajamos, year, month]
# Index: []
#
# [0 rows x 23 columns]

# %%
df_2021_neveike.head(50)
# Out:
#       obj_kodas                                                obj_pav  \
# 4     304639436                               "Mivildos komercija" UAB
# 62    302315574                                        UAB "VRA GROUP"
# 127   141839359                    Uždaroji akcinė bendrovė "PERGAMAS"
# 250   303349572                                    MB "Beta redukcija"
# 277   304896815                                  UAB "Medicinos namai"
# 286   302847381                                  UAB "VILNIAUS BŪSTAI"
# 290   304411920                                           MB "Proupas"
# 326   302649531                              UAB ABBAS MACHINERY STORE
# 338   124361647                     Uždaroji akcinė bendrovė "KELARIS"
# 347   300134041                            UAB "Būsto administravimas"
# 360   305632455                                     MB "Diva boutique"
# 429   304724694                             UAB "Siuvinėjimo meistrai"
# ...

# %% [markdown]
# ##  14

# %%
df_2020["turtas"] = df_2020["trumpalaikis_turtas"] + df_2020["ilgalaikis_turtas"]
df_2021["turtas"] = df_2021["trumpalaikis_turtas"] + df_2021["ilgalaikis_turtas"]
df_2020 = df_2020[df_2020["turtas"] > 0]


cut_labels_5 = ["iki 3k", "3k-20k", "20k-35k", "35k-70k", "70k+"]
df_2020["qaun"] = pd.cut(df_2020["turtas"], bins=5, labels=cut_labels_5)
plot = df_2020.plot.pie(y="qaun", figsize=(5, 5))
# Out:
# C:\Users\adm\AppData\Local\Temp\ipykernel_10588\4105213305.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020["qaun"] = pd.cut(df_2020["turtas"], bins=5, labels=cut_labels_5)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [137], in <cell line: 8>()
#       6 cut_labels_5 = ["iki 3k", "3k-20k", "20k-35k", "35k-70k", "70k+"]
#       7 df_2020["qaun"] = pd.cut(df_2020["turtas"], bins=5, labels=cut_labels_5)
# ----> 8 plot = df_2020.plot.pie(y="qaun", figsize=(5, 5))
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:1584, in PlotAccessor.pie(self, **kwargs)
#    1578 if (
# ...

# %%
my_data = df_2020["qaun"]
my_labels = cut_labels_5
plt.pie(my_data, labels=my_labels, autopct="%1.1f%%")
plt.title("2020 metais")
plt.axis("turtas")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [140], in <cell line: 3>()
#       1 my_data = df_2020["qaun"]
#       2 my_labels = cut_labels_5
# ----> 3 plt.pie(my_data, labels=my_labels, autopct="%1.1f%%")
#       4 plt.title("2020 metais")
#       5 plt.axis("turtas")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2744, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2737 @_copy_docstring_and_deprecators(Axes.pie)
#    2738 def pie(
#    2739         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# -> 2744     return gca().pie(
# ...

# %% [markdown]
# ## 15

# %%
Rasti TOP-100 pelningiausių įmonių pagal “grynasis pelnas” ir TOP-100 įmonių kurių
“nuosavas kapitalas” didžiausias. Ar yra sutampančių įmonių šiuose sąrašuose?
Skaičiuojant TOP įmonės įtraukti viso laikotarpio įmones (naudoti 2020 ir 2021 metų
duomenis kartu). [0.4 taško]

# %%
top100_pelnas = df_abu_metai.copy()

first_answer = top100_pelnas.groupby("obj_pav",'year')["grynasis_pelnas"].nlargest(100)


top100_kapitalas = df_abu_metai.copy()

first_answer = top100_pelnas.groupby("obj_pav",'year')["nuosavas_kapitalas"].nlargest(100)

# %% [markdown]
# ## 16

# %%
16. Ar TOP įmonės pagal “grynasis pelnas” iš 15 užduoties skiriasi pagal metus, t.y. 2020
ir 2021 metais? Kurios įmonės iškrenta iš TOP sąrašo 2021 metais? [0.4 taško]
